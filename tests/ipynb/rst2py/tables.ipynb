# %% [markdown]
# $$
# \def\CC{\bf C}
# \def\QQ{\bf Q}
# \def\RR{\bf R}
# \def\ZZ{\bf Z}
# \def\NN{\bf N}
# $$
# # Table
#
# A simple table:
#
# <table style="width:19%;">
# <colgroup>
# <col width="9%" />
# <col width="9%" />
# </colgroup>
# <tbody>
# <tr class="odd">
# <td>C1</td>
# <td>C2</td>
# </tr>
# <tr class="even">
# <td>a</td>
# <td>b</td>
# </tr>
# <tr class="odd">
# <td>c</td>
# <td>d</td>
# </tr>
# </tbody>
# </table>
#
# A table with more formatting:
#
# <table style="width:19%;">
# <colgroup>
# <col width="9%" />
# <col width="9%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>C1</th>
# <th>C2</th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td>a</td>
# <td>b</td>
# </tr>
# <tr class="even">
# <td>c</td>
# <td>d</td>
# </tr>
# </tbody>
# </table>
